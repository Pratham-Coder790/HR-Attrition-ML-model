# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Collection

# %%
df = pd.read_csv(r'HR Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ### Analysis and Visualizations

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
for i in df.columns:
    print(i)
    print(df[i].nunique())
    print('________________________________________')
# Out:
# Age
# 43
# ________________________________________
# Attrition
# 2
# ________________________________________
# BusinessTravel
# 3
# ________________________________________
# DailyRate
# 886
# ________________________________________
# Department
# 3
# ________________________________________
# DistanceFromHome
# 29
# ________________________________________
# Education
# 5
# ________________________________________
# EducationField
# 6
# ________________________________________
# EmployeeCount
# 1
# ________________________________________
# EmployeeNumber
# 1470
# ________________________________________
# EnvironmentSatisfaction
# 4
# ________________________________________
# Gender
# 2
# ________________________________________
# HourlyRate
# 71
# ________________________________________
# JobInvolvement
# 4
# ________________________________________
# JobLevel
# 5
# ________________________________________
# JobRole
# 9
# ________________________________________
# ...

# %% [markdown]
# #### 1. Attrition Rate

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
plt.pie(df['Attrition'].value_counts(),autopct = '%0.02f%%',labels = ['Yes','No'])
plt.title('Attrition Rate')
plt.show()

# %% [markdown]
# #### 2. Attrition w.r.t Gender

# %%
plt.figure(figsize = (10,5))
sns.countplot(data = df, x = 'Gender', hue = 'Attrition', palette = 'bright')
plt.xlabel('Gender')
plt.ylabel('Attrition')
plt.title('Gender Distribution with Attrition')
plt.show()

# %% [markdown]
# #### 3. Attrition w.r.t Age

# %%
mean_age = df['Age'].mean()

# %%
plt.figure(figsize=(10, 7))
sns.histplot(data=df, x='Age', hue='Attrition', palette='viridis')
sns.set_style('white')
plt.axvline(x=mean_age, color='black', linestyle='--', label=f'Mean Age: {mean_age:.2f}')
plt.title('Age Distribution with Respect to Attrition')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.distplot(x=df['Age'],color='Blue',label='Age')
plt.axvline(x=df['Age'].mean(),color='red',linestyle='--',label='Mean Age: 36.923')
plt.legend()
plt.title('Distribution of Age')
plt.show()

# %% [markdown]
# #### 4. Attrition w.r.t Monthly Income

# %%
average_income = round(df['MonthlyIncome'].mean(),2)

# %%
sns.histplot(data = df, x = 'MonthlyIncome',color = 'Blue', hue = 'Attrition', palette = 'bright')
plt.axvline(round(df['MonthlyIncome'].mean(),2), color='black', linestyle='--', label=f'Average Monthly Income: {average_income}')
plt.text(average_income + 200, 200, f'${average_income}', color='red', verticalalignment='bottom')
plt.title("Attrition w.r.t Salary")
plt.show()

# %% [markdown]
# #### 5. Attrition w.r.t Department

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
df['Department'].value_counts().plot(kind = 'pie', autopct = '%1.2f%%')
plt.title("Attrition w.r.t Department")
plt.show()

# %% [markdown]
# #### 6. Attrition w.r.t Department and Gender

# %%
department_gender_counts = df.groupby(['Department', 'Gender']).size().unstack()
department_gender_counts.plot(kind='pie', autopct='%1.2f%%', figsize=(10, 8), subplots=True, legend = False, labels = None)
plt.subplots_adjust(wspace=1)
labels = department_gender_counts.index
plt.legend(labels=labels, loc='center', bbox_to_anchor=(-0.5, -0.05), ncol=2, title="Department")
plt.show()

# %% [markdown]
# #### 7.Attrition w.r.t Travelling Employees

# %%
len(df.loc[(df['Attrition']=="Yes") & (df['BusinessTravel']=='Non-Travel')])
# Out:
# 12

# %%
len(df.loc[(df['Attrition']=="Yes") & (df['BusinessTravel']=='Travel_Frequently')])
# Out:
# 69

# %%
len(df.loc[(df['Attrition']=="Yes") & (df['BusinessTravel']=='Travel_Rarely')])
# Out:
# 156

# %%
len(df.loc[(df['Attrition']=="Yes")])
# Out:
# 237

# %%
sns.countplot(x=df['BusinessTravel'],hue=df['Attrition'])
plt.title('Attrition w.r.t Travelling employees')
plt.show()

# %% [markdown]
# #### 8. Attrition w.r.t Education Field

# %%
plt.figure(figsize=(10,5))
sns.countplot(data = df, x = 'EducationField',hue = 'Attrition')
plt.title("Attrition w.r.t Education Fields")
plt.show()
print(df['EducationField'].value_counts())
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
df['Attrition']=df['Attrition'].apply(lambda x : 1 if x=='Yes' else 0)

# %% [markdown]
# ### Encode categorical data into numeric values

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()

# %%
colname = df.select_dtypes(object).columns
colname
# Out:
# Index(['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole',
#        'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
df[colname] = oe.fit_transform(df[colname])
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1             2.0       1102         2.0                 1
# 1      49          0             1.0        279         1.0                 8
# 2      37          1             2.0       1373         1.0                 2
# 3      33          0             1.0       1392         1.0                 3
# 4      27          0             2.0        591         1.0                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0             1.0        884         1.0                23
# 1466   39          0             2.0        613         1.0                 6
# 1467   27          0             2.0        155         1.0                 4
# 1468   49          0             1.0       1023         2.0                 2
# 1469   34          0             2.0        628         1.0                 8
#
# ...

# %% [markdown]
# ### Univariate Analysis with Box Plot

# %%
import math
columns = df.columns
num_cols = len(columns)
num_rows = math.ceil(num_cols / 4)
plt.figure(figsize=(15, 5 * num_rows))
for i, column in enumerate(columns, 1):
    plt.subplot(num_rows, 4, i)
    sns.boxplot(y=df[column])
    plt.title(f'Distribution of {column}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation and dropping

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True, linewidth=0.5)
plt.show()

# %%
df.drop(['MonthlyRate','DailyRate','HourlyRate','EmployeeNumber','EmployeeCount','StandardHours','Over18'],axis=1,inplace=True)

# %%
plt.figure(figsize = (20,20))
sns.heatmap(df.corr(), annot = True, linewidth=0.5)
plt.show()

# %% [markdown]
# ### Features & Target

# %%
x = df.iloc[:,2:]
x['Age'] = df.iloc[:,0:1]
y = df.iloc[:,1]

# %% [markdown]
# ### Balancing Data

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE(sampling_strategy='minority') 
x,y=smote.fit_resample(x,y)
y.value_counts()
# Out:
# Attrition
# 1    1233
# 0    1233
# Name: count, dtype: int64

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x, y,test_size=0.2,random_state=42)

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

# %% [markdown]
# ##### Model Evaluation

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score
ac = accuracy_score(y_test,y_pred)
ra = roc_auc_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
cr = classification_report(y_test,y_pred)
print("Accuracy Score :",accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
train = logreg.score(X_train,y_train)
test = logreg.score(X_test,y_test)
print("Training Performance :",train)
print("Testing Performance :",test)
# Out:
# Accuracy Score : 0.8299595141700404
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       250
#            1       0.82      0.84      0.83       244
#
#     accuracy                           0.83       494
#    macro avg       0.83      0.83      0.83       494
# weighted avg       0.83      0.83      0.83       494
#
# Training Performance : 0.8559837728194726
# Testing Performance : 0.8299595141700404

# %% [raw]
# 1. Using Solver 'liblinear'

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(solver = 'liblinear')
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)


from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score
ac = accuracy_score(y_test,y_pred)
ra = roc_auc_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
cr = classification_report(y_test,y_pred)
print("Accuracy Score :",accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
train = logreg.score(X_train,y_train)
test = logreg.score(X_test,y_test)
print("Training Performance :",train)
print("Testing Performance :",test)
# Out:
# Accuracy Score : 0.8299595141700404
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       250
#            1       0.82      0.84      0.83       244
#
#     accuracy                           0.83       494
#    macro avg       0.83      0.83      0.83       494
# weighted avg       0.83      0.83      0.83       494
#
# Training Performance : 0.8554766734279919
# Testing Performance : 0.8299595141700404

# %% [raw]
# 2. Using Solver 'saga'

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(solver = 'saga')
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)


from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score
ac = accuracy_score(y_test,y_pred)
ra = roc_auc_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
cr = classification_report(y_test,y_pred)
print("Accuracy Score :",accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
train = logreg.score(X_train,y_train)
test = logreg.score(X_test,y_test)
print("Training Performance :",train)
print("Testing Performance :",test)
# Out:
# Accuracy Score : 0.8299595141700404
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       250
#            1       0.82      0.84      0.83       244
#
#     accuracy                           0.83       494
#    macro avg       0.83      0.83      0.83       494
# weighted avg       0.83      0.83      0.83       494
#
# Training Performance : 0.8554766734279919
# Testing Performance : 0.8299595141700404

# %% [raw]
# 3. Using Solver 'newton-cholesky'

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(solver = 'newton-cholesky')
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)


from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score
ac = accuracy_score(y_test,y_pred)
ra = roc_auc_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
cr = classification_report(y_test,y_pred)
print("Accuracy Score :",accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
train = logreg.score(X_train,y_train)
test = logreg.score(X_test,y_test)
print("Training Performance :",train)
print("Testing Performance :",test)
# Out:
# Accuracy Score : 0.8299595141700404
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       250
#            1       0.82      0.84      0.83       244
#
#     accuracy                           0.83       494
#    macro avg       0.83      0.83      0.83       494
# weighted avg       0.83      0.83      0.83       494
#
# Training Performance : 0.8554766734279919
# Testing Performance : 0.8299595141700404

# %% [raw]
# 4. Using Solver 'newton-cg'

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(solver = 'newton-cg')
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)


from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score
ac = accuracy_score(y_test,y_pred)
ra = roc_auc_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
cr = classification_report(y_test,y_pred)
print("Accuracy Score :",accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
train = logreg.score(X_train,y_train)
test = logreg.score(X_test,y_test)
print("Training Performance :",train)
print("Testing Performance :",test)
# Out:
# Accuracy Score : 0.8299595141700404
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       250
#            1       0.82      0.84      0.83       244
#
#     accuracy                           0.83       494
#    macro avg       0.83      0.83      0.83       494
# weighted avg       0.83      0.83      0.83       494
#
# Training Performance : 0.8564908722109533
# Testing Performance : 0.8299595141700404

# %% [raw]
# 5. Using Solver 'lbfgs'

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(solver = 'lbfgs')
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)


from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score
ac = accuracy_score(y_test,y_pred)
ra = roc_auc_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
cr = classification_report(y_test,y_pred)
print("Accuracy Score :",accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
train = logreg.score(X_train,y_train)
test = logreg.score(X_test,y_test)
print("Training Performance :",train)
print("Testing Performance :",test)
# Out:
# Accuracy Score : 0.8299595141700404
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       250
#            1       0.82      0.84      0.83       244
#
#     accuracy                           0.83       494
#    macro avg       0.83      0.83      0.83       494
# weighted avg       0.83      0.83      0.83       494
#
# Training Performance : 0.8559837728194726
# Testing Performance : 0.8299595141700404

# %% [markdown]
# #### Naive Bayes

# %%
gb=GaussianNB()
mul=MultinomialNB()
br=BernoulliNB()

# %% [markdown]
# ##### Model Evaluation

# %%
def mymodel(model):
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    train=model.score(X_train,y_train)
    test=model.score(X_test,y_test)
    print("Accuracy Score :",accuracy_score(y_test,y_pred))
    print(classification_report(y_pred,y_test))
    print(f"Trainig ac:{train}\nTesting ac:{test}\n")
    return model

# %% [raw]
# 1. Guassian Naive Bayes

# %%
mymodel(gb)
# Out:
# Accuracy Score : 0.7489878542510121
#               precision    recall  f1-score   support
#
#            0       0.69      0.79      0.74       218
#            1       0.81      0.72      0.76       276
#
#     accuracy                           0.75       494
#    macro avg       0.75      0.75      0.75       494
# weighted avg       0.76      0.75      0.75       494
#
# Trainig ac:0.7540567951318459
# Testing ac:0.7489878542510121
# GaussianNB()

# %% [raw]
# 2. Bernoulli Naive Bayes

# %%
mymodel(br)
# Out:
# Accuracy Score : 0.7469635627530364
#               precision    recall  f1-score   support
#
#            0       0.76      0.75      0.75       253
#            1       0.74      0.75      0.74       241
#
#     accuracy                           0.75       494
#    macro avg       0.75      0.75      0.75       494
# weighted avg       0.75      0.75      0.75       494
#
# Trainig ac:0.7834685598377282
# Testing ac:0.7469635627530364
# BernoulliNB()

# %% [markdown]
# #### Support Vector Machine

# %%
svm = SVC()

# %%
mymodel(svm)
# Out:
# Accuracy Score : 0.8947368421052632
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90       252
#            1       0.89      0.90      0.89       242
#
#     accuracy                           0.89       494
#    macro avg       0.89      0.89      0.89       494
# weighted avg       0.89      0.89      0.89       494
#
# Trainig ac:0.9528397565922921
# Testing ac:0.8947368421052632
# SVC()

# %% [raw]
# 1. Using Kernel 'linear'

# %%
svm=SVC(kernel='linear')
mymodel(svm)
# Out:
# Accuracy Score : 0.8299595141700404
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83       238
#            1       0.85      0.81      0.83       256
#
#     accuracy                           0.83       494
#    macro avg       0.83      0.83      0.83       494
# weighted avg       0.83      0.83      0.83       494
#
# Trainig ac:0.8569979716024341
# Testing ac:0.8299595141700404
# SVC(kernel='linear')

# %% [raw]
# 2. Using Kernel 'poly'

# %%
svm=SVC(kernel='poly')
mymodel(svm)
# Out:
# Accuracy Score : 0.8906882591093117
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89       224
#            1       0.94      0.85      0.89       270
#
#     accuracy                           0.89       494
#    macro avg       0.89      0.89      0.89       494
# weighted avg       0.90      0.89      0.89       494
#
# Trainig ac:0.9619675456389453
# Testing ac:0.8906882591093117
# SVC(kernel='poly')

# %% [raw]
# 3. Using kernel 'rbf'

# %%
svm=SVC(kernel='rbf')
mymodel(svm)
# Out:
# Accuracy Score : 0.8947368421052632
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90       252
#            1       0.89      0.90      0.89       242
#
#     accuracy                           0.89       494
#    macro avg       0.89      0.89      0.89       494
# weighted avg       0.89      0.89      0.89       494
#
# Trainig ac:0.9528397565922921
# Testing ac:0.8947368421052632
# SVC()

# %% [raw]
# 4. Using kernel 'sigmoid'

# %%
svm=SVC(kernel='sigmoid')
mymodel(svm)
# Out:
# Accuracy Score : 0.8097165991902834
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81       244
#            1       0.82      0.80      0.81       250
#
#     accuracy                           0.81       494
#    macro avg       0.81      0.81      0.81       494
# weighted avg       0.81      0.81      0.81       494
#
# Trainig ac:0.7860040567951319
# Testing ac:0.8097165991902834
# SVC(kernel='sigmoid')

# %%
from sklearn.model_selection import GridSearchCV 
param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3) 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.501 total time=   0.1s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.501 total time=   0.1s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.503 total time=   0.1s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.503 total time=   0.1s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.500 total time=   0.1s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.815 total time=   0.1s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.797 total time=   0.1s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.807 total time=   0.1s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.810 total time=   0.1s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.817 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.861 total time=   0.0s
# ...

# %%
print("Best Parameters : ",grid.best_params_)  
print("Best Estimators : ",grid.best_estimator_)
# Out:
# Best Parameters :  {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# Best Estimators :  SVC(C=10, gamma=0.1)

# %%
svm=SVC(kernel='rbf', C =10, gamma = 0.1)
mymodel(svm)
# Out:
# Accuracy Score : 0.9635627530364372
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       252
#            1       0.96      0.97      0.96       242
#
#     accuracy                           0.96       494
#    macro avg       0.96      0.96      0.96       494
# weighted avg       0.96      0.96      0.96       494
#
# Trainig ac:1.0
# Testing ac:0.9635627530364372
# SVC(C=10, gamma=0.1)

# %% [markdown]
# #### Decision Tree

# %%
dt1=DecisionTreeClassifier()
mymodel(dt1)
# Out:
# Accuracy Score : 0.8319838056680162
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83       241
#            1       0.85      0.82      0.83       253
#
#     accuracy                           0.83       494
#    macro avg       0.83      0.83      0.83       494
# weighted avg       0.83      0.83      0.83       494
#
# Trainig ac:1.0
# Testing ac:0.8319838056680162
# DecisionTreeClassifier()

# %% [raw]
# Tuning Max depth

# %%
for i in range(1,51):
    dt1=DecisionTreeClassifier(max_depth=i)
    dt1.fit(X_train,y_train)
    y_pred=dt1.predict(X_test)
    ac=accuracy_score(y_test,y_pred)
    print(f'Max depth={i} accuracy={ac}')
# Out:
# Max depth=1 accuracy=0.7327935222672065
# Max depth=2 accuracy=0.7327935222672065
# Max depth=3 accuracy=0.7793522267206477
# Max depth=4 accuracy=0.8117408906882592
# Max depth=5 accuracy=0.8117408906882592
# Max depth=6 accuracy=0.8340080971659919
# Max depth=7 accuracy=0.840080971659919
# Max depth=8 accuracy=0.8441295546558705
# Max depth=9 accuracy=0.8603238866396761
# Max depth=10 accuracy=0.8481781376518218
# Max depth=11 accuracy=0.8441295546558705
# Max depth=12 accuracy=0.854251012145749
# Max depth=13 accuracy=0.854251012145749
# Max depth=14 accuracy=0.8461538461538461
# Max depth=15 accuracy=0.8441295546558705
# Max depth=16 accuracy=0.840080971659919
# Max depth=17 accuracy=0.8502024291497976
# Max depth=18 accuracy=0.8319838056680162
# Max depth=19 accuracy=0.8461538461538461
# Max depth=20 accuracy=0.840080971659919
# Max depth=21 accuracy=0.8461538461538461
# Max depth=22 accuracy=0.8481781376518218
# Max depth=23 accuracy=0.8441295546558705
# ...

# %%
dt1=DecisionTreeClassifier(max_depth = 9)
mymodel(dt1)
# Out:
# Accuracy Score : 0.8502024291497976
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       242
#            1       0.86      0.84      0.85       252
#
#     accuracy                           0.85       494
#    macro avg       0.85      0.85      0.85       494
# weighted avg       0.85      0.85      0.85       494
#
# Trainig ac:0.9756592292089249
# Testing ac:0.8502024291497976
# DecisionTreeClassifier(max_depth=9)

# %% [raw]
# Tuning min samples split

# %%
for i in range(2,111):
    dt2=DecisionTreeClassifier(min_samples_split=i)
    dt2.fit(X_train,y_train)
    y_pred=dt2.predict(X_test)
    ac=accuracy_score(y_test,y_pred)
    print(f'Min sample split={i} accuracy={ac}')
# Out:
# Min sample split=2 accuracy=0.854251012145749
# Min sample split=3 accuracy=0.8461538461538461
# Min sample split=4 accuracy=0.8441295546558705
# Min sample split=5 accuracy=0.8319838056680162
# Min sample split=6 accuracy=0.840080971659919
# Min sample split=7 accuracy=0.840080971659919
# Min sample split=8 accuracy=0.840080971659919
# Min sample split=9 accuracy=0.8319838056680162
# Min sample split=10 accuracy=0.840080971659919
# Min sample split=11 accuracy=0.8481781376518218
# Min sample split=12 accuracy=0.8522267206477733
# Min sample split=13 accuracy=0.8522267206477733
# Min sample split=14 accuracy=0.8502024291497976
# Min sample split=15 accuracy=0.854251012145749
# Min sample split=16 accuracy=0.8522267206477733
# Min sample split=17 accuracy=0.8502024291497976
# Min sample split=18 accuracy=0.8481781376518218
# Min sample split=19 accuracy=0.8461538461538461
# Min sample split=20 accuracy=0.8380566801619433
# Min sample split=21 accuracy=0.8360323886639676
# ...

# %%
dt1=DecisionTreeClassifier(min_samples_split = 8)
mymodel(dt1)
# Out:
# Accuracy Score : 0.8380566801619433
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84       242
#            1       0.85      0.83      0.84       252
#
#     accuracy                           0.84       494
#    macro avg       0.84      0.84      0.84       494
# weighted avg       0.84      0.84      0.84       494
#
# Trainig ac:0.9776876267748479
# Testing ac:0.8380566801619433
# DecisionTreeClassifier(min_samples_split=8)

# %% [raw]
# Tuning min samples leaf

# %%
for i in range(2,111):
    dt3=DecisionTreeClassifier(min_samples_leaf=i)
    dt3.fit(X_train,y_train)
    y_pred=dt3.predict(X_test)
    ac=accuracy_score(y_test,y_pred)
    print(f'Min sample leaf={i} accuracy={ac}')
# Out:
# Min sample leaf=2 accuracy=0.8360323886639676
# Min sample leaf=3 accuracy=0.840080971659919
# Min sample leaf=4 accuracy=0.854251012145749
# Min sample leaf=5 accuracy=0.868421052631579
# Min sample leaf=6 accuracy=0.8582995951417004
# Min sample leaf=7 accuracy=0.8643724696356275
# Min sample leaf=8 accuracy=0.8663967611336032
# Min sample leaf=9 accuracy=0.868421052631579
# Min sample leaf=10 accuracy=0.8643724696356275
# Min sample leaf=11 accuracy=0.8643724696356275
# Min sample leaf=12 accuracy=0.854251012145749
# Min sample leaf=13 accuracy=0.8603238866396761
# Min sample leaf=14 accuracy=0.8562753036437247
# Min sample leaf=15 accuracy=0.8522267206477733
# Min sample leaf=16 accuracy=0.8360323886639676
# Min sample leaf=17 accuracy=0.8360323886639676
# Min sample leaf=18 accuracy=0.8360323886639676
# Min sample leaf=19 accuracy=0.8360323886639676
# Min sample leaf=20 accuracy=0.8319838056680162
# Min sample leaf=21 accuracy=0.8238866396761133
# ...

# %%
dt1=DecisionTreeClassifier(min_samples_leaf = 3)
mymodel(dt1)
# Out:
# Accuracy Score : 0.8522267206477733
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       231
#            1       0.89      0.83      0.86       263
#
#     accuracy                           0.85       494
#    macro avg       0.85      0.85      0.85       494
# weighted avg       0.86      0.85      0.85       494
#
# Trainig ac:0.9705882352941176
# Testing ac:0.8522267206477733
# DecisionTreeClassifier(min_samples_leaf=3)

# %% [raw]
# Using all the tuned Hyperparameters

# %%
final=DecisionTreeClassifier(max_depth = 9,min_samples_split = 8,min_samples_leaf = 3)
mymodel(final)
# Out:
# Accuracy Score : 0.8461538461538461
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85       242
#            1       0.86      0.83      0.85       252
#
#     accuracy                           0.85       494
#    macro avg       0.85      0.85      0.85       494
# weighted avg       0.85      0.85      0.85       494
#
# Trainig ac:0.9558823529411765
# Testing ac:0.8461538461538461
# DecisionTreeClassifier(max_depth=9, min_samples_leaf=3, min_samples_split=8)

# %% [markdown]
# #### Random Forest

# %%
rf = RandomForestClassifier()
mymodel(rf)
# Out:
# Accuracy Score : 0.9251012145748988
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.93       263
#            1       0.90      0.95      0.92       231
#
#     accuracy                           0.93       494
#    macro avg       0.92      0.93      0.92       494
# weighted avg       0.93      0.93      0.93       494
#
# Trainig ac:1.0
# Testing ac:0.9251012145748988
# RandomForestClassifier()

# %% [markdown]
# #### Voting

# %%
from sklearn.ensemble import VotingClassifier

# %%
Models=[]
Models.append(("Logistic regression",LogisticRegression()))
Models.append(("KNN classifier",KNeighborsClassifier()))
Models.append(("Decision tree classifies",DecisionTreeClassifier()))
Models.append(("Random Forest classifies",RandomForestClassifier()))

# %% [raw]
# 1. Hard Voting

# %%
vt=VotingClassifier(estimators=Models,voting='hard')
vt.fit(X_train,y_train)
y_pred=vt.predict(X_test)

# %%
mymodel(vt)
# Out:
# Accuracy Score : 0.9149797570850202
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92       260
#            1       0.89      0.93      0.91       234
#
#     accuracy                           0.91       494
#    macro avg       0.91      0.92      0.91       494
# weighted avg       0.92      0.91      0.92       494
#
# Trainig ac:0.9964503042596349
# Testing ac:0.9149797570850202
# VotingClassifier(estimators=[('Logistic regression', LogisticRegression()),
#                              ('KNN classifier', KNeighborsClassifier()),
#                              ('Decision tree classifies',
#                               DecisionTreeClassifier()),
#                              ('Random Forest classifies',
#                               RandomForestClassifier())])

# %% [raw]
# 2. Soft Voting

# %%
vt1=VotingClassifier(estimators=Models,voting='soft')
vt1.fit(X_train,y_train)
y_pred=vt.predict(X_test)

# %%
mymodel(vt1)
# Out:
# Accuracy Score : 0.8967611336032388
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90       241
#            1       0.91      0.88      0.90       253
#
#     accuracy                           0.90       494
#    macro avg       0.90      0.90      0.90       494
# weighted avg       0.90      0.90      0.90       494
#
# Trainig ac:0.9989858012170385
# Testing ac:0.8967611336032388
# VotingClassifier(estimators=[('Logistic regression', LogisticRegression()),
#                              ('KNN classifier', KNeighborsClassifier()),
#                              ('Decision tree classifies',
#                               DecisionTreeClassifier()),
#                              ('Random Forest classifies',
#                               RandomForestClassifier())],
#                  voting='soft')

# %% [markdown]
# #### GradientBoost Classifier

# %%
mymodel(gb)
# Out:
# Accuracy Score : 0.7489878542510121
#               precision    recall  f1-score   support
#
#            0       0.69      0.79      0.74       218
#            1       0.81      0.72      0.76       276
#
#     accuracy                           0.75       494
#    macro avg       0.75      0.75      0.75       494
# weighted avg       0.76      0.75      0.75       494
#
# Trainig ac:0.7540567951318459
# Testing ac:0.7489878542510121
# GaussianNB()

# %% [markdown]
# #### AdaBoost Classifier

# %%
ab = AdaBoostClassifier()
mymodel(ab)
# Out:
# Accuracy Score : 0.8967611336032388
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       259
#            1       0.88      0.91      0.89       235
#
#     accuracy                           0.90       494
#    macro avg       0.90      0.90      0.90       494
# weighted avg       0.90      0.90      0.90       494
#
# Trainig ac:0.9158215010141988
# Testing ac:0.8967611336032388
# AdaBoostClassifier()

# %% [markdown]
# #### XGBoost Classifier

# %%
xgb = XGBClassifier()
mymodel(xgb)
# Out:
# Accuracy Score : 0.9271255060728745
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       262
#            1       0.90      0.95      0.92       232
#
#     accuracy                           0.93       494
#    macro avg       0.93      0.93      0.93       494
# weighted avg       0.93      0.93      0.93       494
#
# Trainig ac:1.0
# Testing ac:0.9271255060728745
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
# ...

# %% [markdown]
# #### K Neighbors Classifier

# %%
knn = KNeighborsClassifier()
mymodel(knn)
# Out:
# Accuracy Score : 0.8623481781376519
#               precision    recall  f1-score   support
#
#            0       0.74      0.98      0.84       188
#            1       0.99      0.79      0.88       306
#
#     accuracy                           0.86       494
#    macro avg       0.86      0.89      0.86       494
# weighted avg       0.89      0.86      0.86       494
#
# Trainig ac:0.90973630831643
# Testing ac:0.8623481781376519
# KNeighborsClassifier()

# %% [markdown]
# ### Confusion Matrix for AdaBoost Model

# %%
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(model, X_test, y_test):
    y_pred = model.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    print_confusion_matrix(ab, X_test, y_test)
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Pastel1", xticklabels=["No Attrition", "Attrition"], yticklabels=["No Attrition", "Attrition"],linewidths=1, linecolor='black')
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix")
    plt.show()
plot_confusion_matrix(ab, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[166], line 12
#      10     plt.title("Confusion Matrix")
#      11     plt.show()
# ---> 12 plot_confusion_matrix(ab, X_test, y_test)
#
# Cell In[166], line 5, in plot_confusion_matrix(model, X_test, y_test)
#       3 y_pred = model.predict(X_test)
#       4 cm = confusion_matrix(y_test, y_pred)
# ----> 5 print_confusion_matrix(ab, X_test, y_test)
#       6 plt.figure(figsize=(6, 4))
#       7 sns.heatmap(cm, annot=True, fmt="d", cmap="Pastel1", xticklabels=["No Attrition", "Attrition"], yticklabels=["No Attrition", "Attrition"],linewidths=1, linecolor='black')
#
# NameError: name 'print_confusion_matrix' is not defined
